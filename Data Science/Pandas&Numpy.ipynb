# %%
import pandas as pd
import matplotlib.pyplot as py

# %%
data = {
    'EmpID': [101, 102, 103, 104, 105, 106],
    'Name': ['Ansh', 'Sahil', 'Neha', 'Jayant', 'Priya', 'Rohit'],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR', 'Finance'],
    'Salary': [35000, 45000, 42000, 40000, 37000, 39000],
    'City': ['Delhi', 'Mumbai', 'Delhi', 'Lucknow', 'Mumbai', 'Lucknow']
}

Employee = pd.DataFrame(data)
print("\nEmployee Data:")
print(Employee)

print("\n")
print("-------------------------------------------------------------------------------------------------------------------")

dept_count = Employee['Department'].value_counts()
print("\nEmployee count by Department:")
print(dept_count)

print("\n")
print("-------------------------------------------------------------------------------------------------------------------")

avg_salary = Employee.groupby('Department')['Salary'].mean()
print("\nAverage Salary by Department:")
print(avg_salary)

print("\n")
print("-------------------------------------------------------------------------------------------------------------------")

it_employees=Employee[Employee['Department']=='IT']
print("\n IT department employees")
print(it_employees)

print("\n")
print("-------------------------------------------------------------------------------------------------------------------")

total_salary=Employee['Salary'].sum()
print("\n Total salary of the employee")
print(total_salary)

print("\n")
print("-------------------------------------------------------------------------------------------------------------------")

dept_count.plot(kind='pie',autopct='%1.1f%%',startangle=90,shadow=True)
plt.title("employee distribution by department")
plt.axis("equal")

print("\n")
# Out:
# Employee Data:
#    EmpID    Name Department  Salary     City
# 0    101    Ansh         HR   35000    Delhi
# 1    102   Sahil         IT   45000   Mumbai
# 2    103    Neha         IT   42000    Delhi
# 3    104  Jayant    Finance   40000  Lucknow
# 4    105   Priya         HR   37000   Mumbai
# 5    106   Rohit    Finance   39000  Lucknow
#
#
# -------------------------------------------------------------------------------------------------------------------
#
# Employee count by Department:
# Department
# HR         2
# IT         2
# Finance    2
# Name: count, dtype: int64
#
#
# -------------------------------------------------------------------------------------------------------------------
#
# Average Salary by Department:
# Department
# Finance    39500.0
# HR         36000.0
# IT         43500.0
# Name: Salary, dtype: float64
#
#
# -------------------------------------------------------------------------------------------------------------------
#
# ...
